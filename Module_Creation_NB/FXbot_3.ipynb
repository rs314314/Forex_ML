# %%
import requests
import json
import pandas as pd
import numpy as np
import info
import statistics as stat
import time

# %%
access_token = info.access_token
account_id = info.account_id

static_api = info.static_api
stream_api = info.stream_api

header = {
    'Authorization': f'Bearer {access_token}'
}

# %%
session = requests.Session()

# %%
ins_df = pd.read_pickle('instruments.pkl')

# %%
ins_df
# Out:
#        name      type displayName  pipLocation marginRate
# 0   EUR_HUF  CURRENCY     EUR/HUF           -2       0.05
# 1   EUR_DKK  CURRENCY     EUR/DKK           -4        0.1
# 2   USD_MXN  CURRENCY     USD/MXN           -4       0.10
# 3   GBP_USD  CURRENCY     GBP/USD           -4       0.03
# 4   CAD_CHF  CURRENCY     CAD/CHF           -4       0.04
# ..      ...       ...         ...          ...        ...
# 63  GBP_AUD  CURRENCY     GBP/AUD           -4       0.03
# 64  USD_PLN  CURRENCY     USD/PLN           -4       0.05
# 65  CAD_HKD  CURRENCY     CAD/HKD           -4        0.1
# 66  GBP_CAD  CURRENCY     GBP/CAD           -4       0.03
# 67  GBP_PLN  CURRENCY     GBP/PLN           -4       0.03
#
# [68 rows x 5 columns]

# %%
currencies = ['EUR', 'USD', 'GBP', 'JPY', 'CHF', 'NZD', 'CAD']

# %%
prices = ['mid', 'bid', 'ask']
ohlc = ['o', 'h', 'l', 'c']

# %%
def fetch_candles(pair_name, granularity):
    global header
    url = f'{static_api}/instruments/{pair_name}/candles'
    params = {
        # 'count' : count,
        'granularity' : granularity,
        'price' : 'MBA',
        
    }
    response = session.get(url, params=params, headers=header)
    if response.status_code == 200:
        return response.json()
    else:
        print(response.status_code)
        return f'Error Code: {response.status_code}'

# %%
def get_candles_df(json_response):
    simple_candles = []
    for candle in json_response['candles']:
        if candle['complete'] == False:
            continue
        new_dict = {}
        new_dict['time'] = candle['time']
        new_dict['volume'] = candle['volume']
        for p in prices:
            for e in ohlc:
                new_dict[f'{p}_{e}'] = candle[p][e]
        simple_candles.append(new_dict)
    return pd.DataFrame.from_dict(simple_candles)

# %%
def save_candles(candles_df, pair, granularity):
    candles_df.to_pickle(f'candles_data/{pair}_{granularity}.pkl')

# %%
for p1 in currencies:
    for p2 in currencies:
        pair = f'{p1}_{p2}'
        if pair in ins_df.name.unique():
            create_data(pair, 'H1')

# %%
EUR_USD = pd.read_pickle('candles_data/EUR_USD_H1.pkl')

# %%
EUR_USD
# Out:
#                                time  volume    mid_o    mid_h    mid_l  \
# 0    2022-05-02T00:00:00.000000000Z    9726  1.05349  1.05532  1.05267
# 1    2022-05-02T01:00:00.000000000Z    7057  1.05294  1.05336  1.05216
# 2    2022-05-02T02:00:00.000000000Z    4465  1.05244  1.05277  1.05180
# 3    2022-05-02T03:00:00.000000000Z    5004  1.05210  1.05276  1.05174
# 4    2022-05-02T04:00:00.000000000Z    4011  1.05242  1.05246  1.05169
# ..                              ...     ...      ...      ...      ...
# 494  2022-05-30T16:00:00.000000000Z    2736  1.07796  1.07866  1.07781
# 495  2022-05-30T17:00:00.000000000Z    1211  1.07862  1.07870  1.07824
# 496  2022-05-30T18:00:00.000000000Z    1087  1.07840  1.07848  1.07806
# 497  2022-05-30T19:00:00.000000000Z    1675  1.07834  1.07838  1.07772
# 498  2022-05-30T20:00:00.000000000Z    1255  1.07792  1.07826  1.07782
#
#        mid_c    bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l  \
# 0    1.05294  1.05339  1.05524  1.05258  1.05285  1.05359  1.05542  1.05276
# 1    1.05245  1.05284  1.05329  1.05208  1.05236  1.05304  1.05343  1.05225
# 2    1.05210  1.05236  1.05268  1.05169  1.05202  1.05253  1.05287  1.05190
# 3    1.05242  1.05202  1.05267  1.05165  1.05234  1.05219  1.05284  1.05182
# 4    1.05186  1.05233  1.05237  1.05159  1.05178  1.05251  1.05256  1.05178
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 494  1.07864  1.07788  1.07857  1.07773  1.07855  1.07804  1.07874  1.07789
# 495  1.07842  1.07853  1.07861  1.07814  1.07833  1.07871  1.07878  1.07832
# 496  1.07834  1.07831  1.07839  1.07796  1.07826  1.07849  1.07857  1.07815
# 497  1.07792  1.07826  1.07830  1.07763  1.07782  1.07841  1.07847  1.07782
# 498  1.07800  1.07783  1.07817  1.07771  1.07786  1.07802  1.07836  1.07791
#
#        ask_c
# 0    1.05303
# 1    1.05254
# 2    1.05217
# 3    1.05251
# 4    1.05195
# ..       ...
# 494  1.07872
# 495  1.07851
# 496  1.07843
# 497  1.07803
# 498  1.07813
#
# [499 rows x 14 columns]

# %%
EUR_USD['mid_o'][0]
# Out:
# '1.05349'

# %%
len(EUR_USD.index)
# Out:
# 499

# %%
test = EUR_USD.copy()

# %%
non_cols = ['time', 'volume']
cols = [x for x in test.columns if x not in non_cols]
test[cols] = test[cols].apply(pd.to_numeric)

# %%
test.head()
# Out:
#                              time  volume    mid_o    mid_h    mid_l    mid_c  \
# 0  2022-05-02T00:00:00.000000000Z    9726  1.05349  1.05532  1.05267  1.05294
# 1  2022-05-02T01:00:00.000000000Z    7057  1.05294  1.05336  1.05216  1.05245
# 2  2022-05-02T02:00:00.000000000Z    4465  1.05244  1.05277  1.05180  1.05210
# 3  2022-05-02T03:00:00.000000000Z    5004  1.05210  1.05276  1.05174  1.05242
# 4  2022-05-02T04:00:00.000000000Z    4011  1.05242  1.05246  1.05169  1.05186
#
#      bid_o    bid_h    bid_l    bid_c    ask_o    ask_h    ask_l    ask_c
# 0  1.05339  1.05524  1.05258  1.05285  1.05359  1.05542  1.05276  1.05303
# 1  1.05284  1.05329  1.05208  1.05236  1.05304  1.05343  1.05225  1.05254
# 2  1.05236  1.05268  1.05169  1.05202  1.05253  1.05287  1.05190  1.05217
# 3  1.05202  1.05267  1.05165  1.05234  1.05219  1.05284  1.05182  1.05251
# 4  1.05233  1.05237  1.05159  1.05178  1.05251  1.05256  1.05178  1.05195

# %%
def average_true_range(candles, length):
    if type(length) != int or length < 1:
        print('invalid length')
        return None

    tr = [abs(candles['mid_h'][0] - candles['mid_l'][0])]
    for i in range(1, len(candles.index)):
        a = abs(candles['mid_h'][i] - candles['mid_l'][i])
        b = abs(candles['mid_h'][i] - candles['mid_l'][i-1])
        c = abs(candles['mid_h'][i-1] - candles['mid_l'][i])
        tr.append(max(a,b,c))
    atr = [stat.mean(tr[x-length+1 : x+2]) if x >= length-1 else None for x in range(len(candles.index))]
    candles[f'atr_{length}'] = atr

    return

average_true_range(test, 14)
test.head(30)
# Out:
#                               time  volume    mid_o    mid_h    mid_l  \
# 0   2022-05-02T00:00:00.000000000Z    9726  1.05349  1.05532  1.05267
# 9   1.05270  1.05281  1.05322  1.05179  1.05262  1.05300  1.05339  1.05197
# 10  1.05264  1.05264  1.05286  1.05190  1.05256  1.05279  1.05301  1.05207
# 11  1.05168  1.05255  1.05271  1.05129  1.05160  1.05271  1.05287  1.05145
# 12  1.05106  1.05157  1.05321  1.05075  1.05097  1.05174  1.05338  1.05093
# 13  1.05242  1.05098  1.05272  1.05019  1.05229  1.05115  1.05289  1.05036
# 14  1.05223  1.05233  1.05411  1.05141  1.05216  1.05258  1.05427  1.05157
# 15  1.05216  1.05216  1.05231  1.05033  1.05208  1.05231  1.05246  1.05048
# 16  1.05092  1.05206  1.05256  1.05014  1.05082  1.05221  1.05272  1.05030
# 17  1.04933  1.05084  1.05101  1.04920  1.04925  1.05101  1.05117  1.04936
# 18  1.04921  1.04926  1.04989  1.04895  1.04913  1.04941  1.05005  1.04912
# 19  1.05043  1.04913  1.05108  1.04907  1.05034  1.04928  1.05126  1.04924
# 20  1.05076  1.05034  1.05075  1.05008  1.05066  1.05050  1.05093  1.05025
# 21  1.05064  1.04979  1.05033  1.04979  1.05030  1.05079  1.05132  1.05079
# 22  1.05102  1.05027  1.05128  1.05027  1.05093  1.05101  1.05147  1.05068
# 23  1.05096  1.05093  1.05102  1.05049  1.05089  1.05113  1.05120  1.05068
# 24  1.05253  1.05088  1.05251  1.05077  1.05244  1.05104  1.05269  1.05094
# 25  1.05224  1.05245  1.05259  1.05143  1.05215  1.05261  1.05277  1.05159
# 26  1.05136  1.05216  1.05251  1.05091  1.05128  1.05232  1.05267  1.05108
# 27  1.05185  1.05127  1.05188  1.05071  1.05176  1.05145  1.05205  1.05087
# 28  1.05018  1.05178  1.05232  1.05008  1.05010  1.05194  1.05251  1.05026
# 29  1.05074  1.05009  1.05098  1.04968  1.05065  1.05027  1.05118  1.04987
#
#       ask_c    atr_14
# 0   1.05303       NaN
# 1   1.05254       NaN
# 2   1.05217       NaN
# 3   1.05251       NaN
# 4   1.05195       NaN
# 5   1.05144       NaN
# 6   1.05494       NaN
# 7   1.05334       NaN
# 8   1.05300       NaN
# 9   1.05278       NaN
# 10  1.05273       NaN
# 11  1.05175       NaN
# 12  1.05115       NaN
# 13  1.05254  0.002609
# 14  1.05230  0.002685
# 15  1.05223  0.002635
# 16  1.05101  0.002755
# 17  1.04941  0.002823
# 18  1.04929  0.002893
# 19  1.05052  0.002911
# 20  1.05086  0.002677
# 21  1.05098  0.002361
# 22  1.05111  0.002128
# 23  1.05104  0.002146
# 24  1.05262  0.002181
# 25  1.05232  0.002189
# 26  1.05144  0.002144
# 27  1.05194  0.002092
# 28  1.05026  0.002008
# 29  1.05084  0.001863

# %%
def relative_strength_index(candles, length=14, price='mid'):
    change = [(candles[f'{price}_c'][row] - candles[f'{price}_o'][row]) for row in range(len(candles))]
    pos = [max(x, 0) for x in change]
    neg = [abs(min(x, 0)) for x in change]
    cag = stat.mean(pos[0: length])
    cal = stat.mean(neg[0: length])
    rs = [None] * (length - 1)
    rs.append(100 - (100 / (1 + (cag / cal))))

    for x in range((length), len(change)):
        cag = ((cag * 13) + pos[x]) / length
        cal = ((cal * 13) + neg[x]) / length

        rs.append(100 - (100 / (1 + (cag / (cal)))))

